# %%
import pandas as pd

# %%
data = pd.read_csv('call\기준금리(forGraph).csv', usecols = [1,2])

# %%
data.head()
# Out:
#          date  basemoney
# 0  2005-01-01       3.25
# 1  2005-01-02       3.25
# 2  2005-01-03       3.25
# 3  2005-01-04       3.25
# 4  2005-01-05       3.25

# %%
data3 = pd.read_csv('call\기준금리.csv')
data3.columns = ['date', 'basemoney']
data3
# Out:
#           date  basemoney
# 0   2019-07-18       1.50
# 1   2018-11-30       1.75
# 2   2017-11-30       1.50
# 3   2016-06-09       1.25
# 4   2015-06-11       1.50
# 5   2015-03-12       1.75
# 6   2014-10-15       2.00
# 7   2014-08-14       2.25
# 8   2013-05-09       2.50
# 9   2012-10-11       2.75
# 10  2012-07-12       3.00
# 11  2011-06-10       3.25
# 12  2011-03-10       3.00
# 13  2011-01-13       2.75
# 14  2010-11-16       2.50
# 15  2010-07-09       2.25
# 16  2009-02-12       2.00
# 17  2009-01-09       2.50
# 18  2008-12-11       3.00
# 19  2008-11-07       4.00
# 20  2008-10-27       4.25
# 21  2008-10-09       5.00
# 22  2008-08-07       5.25
# 23  2007-08-09       5.00
# 24  2007-07-12       4.75
# 25  2006-08-10       4.50
# 26  2006-06-08       4.25
# 27  2006-02-09       4.00
# 28  2005-12-08       3.75
# 29  2005-10-11       3.50
# 30  2004-11-11       3.25
# 31  2004-08-12       3.50
# 32  2003-07-10       3.75
# 33  2003-05-13       4.00
# ...

# %%
data2 = pd.read_csv('call\call_finish-Copy1.csv')

# %%
data2.head()
# Out:
#          date      tone
# 0  2005-06-09  1.000000
# 1  2005-07-07 -1.000000
# 2  2005-08-11  0.428571
# 3  2005-09-08 -0.333333
# 4  2005-10-11  0.000000

# %%
copy = data
copy2 = data2
copy3 = data3

# %%
df = copy2.merge(copy, on = 'date', how = 'left')
df.head()
# Out:
#          date      tone  basemoney
# 0  2005-06-09  1.000000       3.25
# 1  2005-07-07 -1.000000       3.25
# 2  2005-08-11  0.428571       3.25
# 3  2005-09-08 -0.333333       3.25
# 4  2005-10-11  0.000000       3.50

# %%
corr = df.corr(method = 'pearson')
corr
# Out:
#               tone  basemoney
# tone       1.00000    0.54348
# basemoney  0.54348    1.00000

# %%
df2 = copy2.merge(copy3, on = 'date', how = 'left')
df2.head()
# Out:
#          date      tone  basemoney
# 0  2005-06-09  1.000000        NaN
# 1  2005-07-07 -1.000000        NaN
# 2  2005-08-11  0.428571        NaN
# 3  2005-09-08 -0.333333        NaN
# 4  2005-10-11  0.000000        3.5

# %%
df2.to_csv('수작업용기준금리.csv')

# %%
corr = df2.corr(method = 'pearson')
corr
# Out:
#                tone  basemoney
# tone       1.000000   0.721634
# basemoney  0.721634   1.000000

# %%
data4 = pd.read_csv('기준금리_빈값을 선형으로 채운데이터.csv')
data4.head()
# Out:
#    Unnamed: 0        date      tone  basemoney
# 0         NaN  2004-11-11       NaN       3.25
# 1         0.0  2005-06-09  1.000000       3.30
# 2         1.0  2005-07-07 -1.000000       3.35
# 3         2.0  2005-08-11  0.428571       3.40
# 4         3.0  2005-09-08 -0.333333       3.45

# %%
# 선형
corr = data4.corr(method = 'pearson')
corr
# Out:
#             Unnamed: 0      tone  basemoney
# Unnamed: 0    1.000000 -0.478405  -0.881860
# tone         -0.478405  1.000000   0.605013
# basemoney    -0.881860  0.605013   1.000000

# %% [markdown]
# # 데이터 채우기 위해 날짜부터 채우기

# %%
df2.head()
# 2004-11-11	3.25?
# Out:
#          date      tone  basemoney
# 0  2005-06-09  1.000000        NaN
# 1  2005-07-07 -1.000000        NaN
# 2  2005-08-11  0.428571        NaN
# 3  2005-09-08 -0.333333        NaN
# 4  2005-10-11  0.000000        3.5

# %%
date_data = pd.date_range(start=date(2004, 11, 11), end=date(2017,12,31))
date_data = pd.DataFrame(date_data, columns = ['date'])
date_data.head()
# Out:
#         date
# 0 2004-11-11
# 1 2004-11-12
# 2 2004-11-13
# 3 2004-11-14
# 4 2004-11-15

# %%
df2['date'] = pd.to_datetime(df2['date'])
df2.head()
# Out:
#         date      tone  basemoney
# 0 2005-06-09  1.000000        NaN
# 1 2005-07-07 -1.000000        NaN
# 2 2005-08-11  0.428571        NaN
# 3 2005-09-08 -0.333333        NaN
# 4 2005-10-11  0.000000        3.5

# %%
df2['date'] = pd.to_datetime(df2['date']).apply(lambda x: x.date()).values

# %%
df2.loc[0, 'date']
df2
# Out:
#           date      tone  basemoney
# 0   2005-06-09  1.000000        NaN
# 1   2005-07-07 -1.000000        NaN
# 2   2005-08-11  0.428571        NaN
# 3   2005-09-08 -0.333333        NaN
# 4   2005-10-11  0.000000       3.50
# 5   2005-11-10  0.000000        NaN
# 6   2005-12-08  0.750000       3.75
# 7   2006-01-12  0.200000        NaN
# 8   2006-02-09  0.500000       4.00
# 9   2006-03-09  1.000000        NaN
# 10  2006-04-07 -0.333333        NaN
# 11  2006-05-11  0.000000        NaN
# 12  2006-06-08  0.142857       4.25
# 13  2006-07-07  1.000000        NaN
# 14  2006-08-10  0.400000       4.50
# 15  2006-09-07  0.000000        NaN
# 16  2006-10-12  0.250000        NaN
# 17  2006-11-09  0.500000        NaN
# 18  2006-12-07  0.333333        NaN
# 19  2007-01-11  0.142857        NaN
# 20  2007-02-08  1.000000        NaN
# 21  2007-03-08  0.538462        NaN
# 22  2007-04-12  0.200000        NaN
# 23  2007-05-10  0.000000        NaN
# 24  2007-07-12 -0.250000       4.75
# ...

# %%
date_data.loc[0, 'date']
# Out:
# datetime.date(2004, 11, 11)

# %%
date_data['date'] = pd.to_datetime(date_data['date']).apply(lambda x: x.date()).values

# %%
file = pd.read_excel('날짜기준선형.xlsx')
file.head()
# Out:
#         date  tone        선형
# 0 2004-11-11   NaN  3.250000
# 1 2004-11-12   NaN  3.250749
# 2 2004-11-13   NaN  3.251497
# 3 2004-11-14   NaN  3.252246
# 4 2004-11-15   NaN  3.252994

# %%
file_copy = file.dropna()

# %%
file_copy.head()
# Out:
#           date      tone        선형
# 210 2005-06-09  1.000000  3.407186
# 238 2005-07-07 -1.000000  3.428144
# 273 2005-08-11  0.428571  3.454341
# 301 2005-09-08 -0.333333  3.475299
# 334 2005-10-11  0.000000  3.500000

# %%
data4 = pd.read_csv('기준금리_빈값을 선형으로 채운데이터.csv', usecols = [1, 3])
data4.columns = ['date', '칸수기준']
data4 = data4[1:]
data4 = data4.reset_index(drop = True)
data4.head()
# Out:
#          date  칸수기준
# 0  2005-06-09  3.30
# 1  2005-07-07  3.35
# 2  2005-08-11  3.40
# 3  2005-09-08  3.45
# 4  2005-10-11  3.50

# %%
# 선형
corr = file_copy.corr(method = 'pearson')
corr
# Out:
#           tone        선형
# tone  1.000000  0.561637
# 선형    0.561637  1.000000
