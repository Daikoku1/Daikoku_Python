# %%
# !pip install pdfminer.six
# Out:
# Requirement already satisfied: pdfminer.six in c:\programdata\anaconda3\lib\site-packages (20181108)
# Requirement already satisfied: pycryptodome in c:\programdata\anaconda3\lib\site-packages (from pdfminer.six) (3.8.2)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\lib\site-packages (from pdfminer.six) (2.1.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from pdfminer.six) (1.12.0)

# %%
import sys
reload(sys)
sys.setdefaultencoding('utf-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-950f405c2af5> in <module>
#       1 import sys
#       2
# ----> 3 reload(sys)
#       4
#       5 sys.setdefaultencoding('utf-8')
#
# NameError: name 'reload' is not defined

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import BytesIO

def pdf_to_text(path):
    manager = PDFResourceManager()
    retstr = BytesIO()
    layout = LAParams(all_texts=True)
    device = TextConverter(manager, retstr, laparams=layout)
    filepath = open(path, 'rb')
    interpreter = PDFPageInterpreter(manager, device)

    for page in PDFPage.get_pages(filepath, check_extractable=True):
        interpreter.process_page(page)

    text = retstr.getvalue()

    filepath.close()
    device.close()
    retstr.close()
    return text


# if __name__ == "__main__":
#     text = pdf_to_text("yourfile.pdf")
#     print(text)

# %%
#-*- coding:utf-8 -*-
pdf_to_text('file_1p,0.pdf')
# Out:
# b'2019\xeb\x85\x84\xeb\x8f\x84 \xec\xa0\x9c12\xec\xb0\xa8\n\n\xea\xb8\x88\xec\x9c\xb5\xed\x86\xb5\xed\x99\x94\xec\x9c\x84\xec\x9b\x90\xed\x9a\x8c(\xec\xa0\x95\xea\xb8\xb0) \xec\x9d\x98\xec\x82\xac\xeb\xa1\x9d\n\n\xed\x95\x9c \xea\xb5\xad \xec\x9d\x80 \xed\x96\x89\n\n\x0c1. \xec\x9d\xbc\n\n2. \xec\x9e\xa5\n\n\xec\x9e\x90\n\n\xec\x86\x8c\n\n3. \xec\xb6\x9c\xec\x84\x9d\xec\x9c\x84\xec\x9b\x90\n\n2019\xeb\x85\x84 6\xec\x9b\x94 20\xec\x9d\xbc(\xeb\xaa\xa9)\n\n\xea\xb8\x88\xec\x9c\xb5\xed\x86\xb5\xed\x99\x94\xec\x9c\x84\xec\x9b\x90\xed\x9a\x8c \xed\x9a\x8c\xec\x9d\x98\xec\x8b\xa4\n\n\xec\x9d\xb4 \xec\xa3\xbc \xec\x97\xb4 \xec\x9d\x98 \xec\x9e\xa5(\xec\xb4\x9d\xec\x9e\xac)\n\xec\x9d\xb4 \xec\x9d\xbc \xed\x98\x95 \xec\x9c\x84 \xec\x9b\x90\n\xec\xa1\xb0 \xeb\x8f\x99 \xec\xb2\xa0 \xec\x9c\x84 \xec\x9b\x90\n\xea\xb3\xa0 \xec\x8a\xb9 \xeb\xb2\x94 \xec\x9c\x84 \xec\x9b\x90\n\xec\x8b\xa0 \xec\x9d\xb8 \xec\x84\x9d \xec\x9c\x84 \xec\x9b\x90\n\xec\x9c\xa4 \xeb\xa9\xb4 \xec\x8b\x9d \xec\x9c\x84 \xec\x9b\x90(\xeb\xb6\x80\xec\xb4\x9d\xec\x9e\xac)\n\xec\x9e\x84 \xec\xa7\x80 \xec\x9b\x90 \xec\x9c\x84 \xec\x9b\x90\n\n4. \xea\xb2\xb0\xec\x84\x9d\xec\x9c\x84\xec\x9b\x90\n\n\xec\x97\x86 \xec\x9d\x8c\n\n\xec\x9e\xa5 \xed\x98\xb8 \xed\x98\x84 \xea\xb0\x90 \xec\x82\xac\n\xec\x8b\xa0 \xed\x98\xb8 \xec\x88\x9c \xeb\xb6\x80\xec\xb4\x9d\xec\x9e\xac\xeb\xb3\xb4\n\xec\xa0\x95 \xea\xb7\x9c \xec\x9d\xbc \xeb\xb6\x80\xec\xb4\x9d\xec\x9e\xac\xeb\xb3\xb4\n\xec\x84\x9c \xeb\xb4\x89 \xea\xb5\xad \xec\x99\xb8\xec\x9e\x90\xec\x9a\xb4\xec\x9a\xa9\xec\x9b\x90\xec\x9e\xa5\n\xeb\xaf\xbc \xec\xa2\x8c \xed\x99\x8d \xea\xb8\x88\xec\x9c\xb5\xec\x95\x88\xec\xa0\x95\xea\xb5\xad\xec\x9e\xa5\n\xec\x9d\xb4 \xec\x83\x81 \xed\x98\x95 \xea\xb8\x88\xec\x9c\xb5\xec\x8b\x9c\xec\x9e