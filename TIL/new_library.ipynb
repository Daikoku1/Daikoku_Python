# %%
# !pip install bamboolib
# Out:
# ...
#   Using cached bamboolib-1.26.0-cp39-cp39-win_amd64.whl (6.2 MB)
# ...
#   Using cached cryptography-2.9.2.tar.gz (517 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Using cached analytics_python-1.2.9-py2.py3-none-any.whl (13 kB)
# ...
#   Using cached plotly-4.14.3-py2.py3-none-any.whl (13.2 MB)
# ...
#   Using cached seaborn-0.10.1-py3-none-any.whl (215 kB)
# ...
#   Using cached ppscore-1.2.0-py2.py3-none-any.whl
# ...
#   Using cached ipyslickgrid-0.0.3-py2.py3-none-any.whl
# ...
#   Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# ...
#   Using cached psutil-5.8.0-cp39-cp39-win_amd64.whl (246 kB)
# ...
#   ERROR: Command errored out with exit status 1:
# ...

# %%
import bamboolib as bam
import pandas as pd
df = pd.read_csv(bam.titanic_csv)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7104/2124511319.py in <module>
# ----> 1 import bamboolib as bam
#       2 import pandas as pd
#       3 df = pd.read_csv(bam.titanic_csv)
#
# ModuleNotFoundError: No module named 'bamboolib'

# %%
df
